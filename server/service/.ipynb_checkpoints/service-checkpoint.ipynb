# %%
import pyproj
import math
import folium
import json
import os
from flatten_json import flatten
import pandas as pd

import pandas as pd
import geopandas as gpd
gpd.datasets.available
import geoplot
import geoplot.crs as gcrs

from shapely.geometry import Polygon, shape, box
from shapely.ops import transform

data = gpd.read_file("/home/gmiak/Master_thesis/refugee_camp_project/server/data/yusuf/camp_boundaries.geojson")

fig = geoplot.polyplot(data, projection=gcrs.AlbersEqualArea(), edgecolor='darkgrey', facecolor='lightgrey', linewidth=.3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 22
#      18 data = gpd.read_file("/home/gmiak/Master_thesis/refugee_camp_project/server/data/yusuf/camp_boundaries.geojson")
#      20 fig = geoplot.polyplot(data, projection=gcrs.AlbersEqualArea(), edgecolor='darkgrey', facecolor='lightgrey', linewidth=.3)
# ---> 22 fig.save()
#
# AttributeError: 'GeoAxes' object has no attribute 'save'
